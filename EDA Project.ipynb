# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings("ignore")
df= pd.read_csv(r"C:\Users\Lenovo\Downloads\shreya.zip",header=0,index_col=0)
df
# Out:
#             type                  title        directors  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast      countries  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head()
# Out:
#             type                  title        directors  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast      countries  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8807 entries, s1 to s8807
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   title         8807 non-null   object
#  2   directors     6173 non-null   object
#  3   cast          7982 non-null   object
#  4   countries     7976 non-null   object
#  5   date_added    8797 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8803 non-null   object
#  8   duration      8804 non-null   object
#  9   listed_in     8807 non-null   object
#  10  description   8807 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 825.7+ KB

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
#1: How many movies and TV shows are there?
sns.countplot(data=df, x='type',palette='pastel')
plt.title('Count of Movies vs TV Shows')
plt.show()

# %%
df['listed_in'].value_counts().head(10)
# Out:
# listed_in
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# Kids' TV                                            220
# Children & Family Movies                            215
# Children & Family Movies, Comedies                  201
# Documentaries, International Movies                 186
# Dramas, International Movies, Romantic Movies       180
# Name: count, dtype: int64

# %%
#2: How many titles were added each year?
df['date_added'] = pd.to_datetime(df['date_added'])
df['year_added'] = df['date_added'].dt.year
titles_per_year = df['year_added'].value_counts().sort_index()
print(titles_per_year)
titles_per_year.plot(kind='bar', figsize=(12,6), title='Titles Added Each Year',color='pink')
plt.show()
# Out:
# year_added
# 2008.0       2
# 2009.0       2
# 2010.0       1
# 2011.0      13
# 2012.0       3
# 2013.0      11
# 2014.0      24
# 2015.0      82
# 2016.0     429
# 2017.0    1188
# 2018.0    1649
# 2019.0    2016
# 2020.0    1879
# 2021.0    1498
# Name: count, dtype: int64

# %%
# 3: What is the most common genre?
genre_df = pd.DataFrame(top_genres, columns=['Genre', 'Count'])

# Pie chart
plt.figure(figsize=(8,8))
plt.pie(genre_df['Count'],
        labels=genre_df['Genre'],
        autopct='%1.1f%%',
        startangle=140,
        colors=sns.color_palette('pastel'),
        wedgeprops={'edgecolor': 'black'})

plt.title('Top 10 Most Common Genres on Netflix')
plt.show()

# %%
#4: Which countries produce the most content?
country_counts = df['countries'].value_counts().head(10)

plt.figure(figsize=(10,5))
sns.barplot(x=country_counts.values, y=country_counts.index, palette='coolwarm')
plt.title('Top 10 Countries by Netflix Content')
plt.xlabel('Number of Titles')
plt.ylabel('Country')
plt.show()

# %%
#5: Distribution of movie durations
# Only movies
movies = df[df['type'] == 'Movie'].copy()

# Extract duration in minutes
movies['duration'] = movies['duration'].str.replace(' min','').astype(float)

# Visualization
sns.histplot(movies['duration'], bins=20, kde=True)
plt.title('Distribution of Movie Duration')
plt.xlabel('Duration (minutes)')
plt.show()

# %%
#6: Ratings analysis
df['rating'] = df['rating'].fillna('Not Rated')
rating_counts = df['rating'].value_counts()
print(rating_counts)
sns.countplot(data=df, y='rating', order=rating_counts.index)
plt.title('Count of Ratings')
plt.show()
# Out:
# rating
# TV-MA        3207
# TV-14        2160
# TV-PG         863
# R             799
# PG-13         490
# TV-Y7         334
# TV-Y          307
# PG            287
# TV-G          220
# NR             80
# G              41
# TV-Y7-FV        6
# Not Rated       4
# NC-17           3
# UR              3
# 66 min          1
# 74 min          1
# 84 min          1
# Name: count, dtype: int64

# %% [markdown]
# * TV-MA has 3000 count

# %%
directors = df['directors'].value_counts().head(10)
plt.figure(figsize=(9,5))
sns.barplot(x=directors.values, y=directors.index, palette='mako')
plt.title('Top 10 Directors with Most Titles on Netflix')
plt.xlabel('Number of Titles')
plt.ylabel('Directors')
plt.show()

# %%
directors = df['directors'].value_counts().head(10)
plt.figure(figsize=(9,5))
sns.barplot(x=directors.values, y=directors.index, palette='mako')
plt.title('Top 10 Directors with Most Titles on Netflix')
plt.xlabel('Number of Titles')
plt.ylabel('Directors')
plt.show()

# %% [markdown]
#  * The top director who  have worked on multiple Netflix originals and popular titles is Rajiv Chilaka with almost 17.5.

# %%
from collections import Counter
cast_exploded = df['cast'].str.split(', ').explode()
top_actors = cast_exploded.value_counts().head(10).reset_index()
top_actors.columns = ['Actor', 'Count']
plt.figure(figsize=(9,5))
sns.barplot(x='Count', y='Actor', data=top_actors, palette='crest')
plt.title('Top 10 Most Frequent Actors on Netflix')
plt.xlabel('Number of Titles')
plt.ylabel('Actor')
plt.show()

# %% [markdown]
# * These actors appear most frequently across Netflix titles
